# %% [markdown]
# # Customer Segmentation & Risk Evaluation
# This notebook documents customer segment creation and risk scoring.

# %%
import pandas as pd
from pathlib import Path
BASE = Path("/Users/huseyn/Desktop/customer-segmentation-risk-evaluation")
df = pd.read_csv(BASE / "data" / "processed" / "risk_scored_customers.csv")
df.head()
